# %%
import pandas as pd

# %%
df=pd.read_csv("advertising.csv")

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
min(df)
# Out:
# 'Newspaper'

# %%
df.isna().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
from matplotlib import pyplot as plt
x=df['TV']
y=df['Sales']
plt.plot(x)

# %%
plt.scatter(x,y)

# %%
#experience is inserted as a data in a machine,so  data is cateogrised into 3 parts:training,testing,validation
#training:giving inputs and making machine learn
#testing:to check the outputs
#validation data
#linear regression is used to predict the  y  intermediate value to corresponding x.
#the graph will try to put all the coordinates in 1 line ,

# %%
x.shape
# Out:
# (200,)

# %%
import numpy as np    
#to create an array 

# Create a sample 2D array
x = np.array(x)
y= np.array(y)

# Reshape x to be a column vector
x_reshaped = x.reshape(-1, 1)

print("Original shape:", x.shape)
print("Reshaped shape:", x_reshaped.shape)
# Out:
# Original shape: (200,)
# Reshaped shape: (200, 1)

# %%
#split x and y into training and test data sets
#random_state--the set of data does not change
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
# print the dimensions of x_train,x_test,y_train,y_test
# print(x_train)

print(x_train.shape) # 70% in training,30% in testing and then random size =32 to keep the sample size same

print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (140,)
# (140,)
# (60,)
# (60,)

# %%
from sklearn.linear_model import LinearRegression

lm=LinearRegression()

#tRAIN THE DATA model using training data sets
from sklearn.linear_model import LinearRegression
# Ensure x_train is 2D
# If x_train is already 2D, this step can be skipped
if x_train.ndim == 1:
    x_train = x_train.reshape(-1, 1)
if x_test.ndim == 1:
    x_test = x_test.reshape(-1, 1)

# Instantiate the model
lm = LinearRegression()


# Fit the model on the training data
lm.fit(x_train, y_train)


# Predict on the test set
y_pred = lm.predict(x_test)

# %%
#visualising the test set results
plt.scatter(x_test,y_test,color="red")
plt.plot(x_test,)

# %%
#visualising

# %%
slope=lm.coef_
intercept=lm.intercept_,
print("Estimated model slope:",slope)
print("Estimated model intercept:",intercept)
# Out:
# Estimated model slope: [0.05483488]
# Estimated model intercept: (7.206554548173253,)
